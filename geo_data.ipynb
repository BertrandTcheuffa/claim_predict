# %%
import pandas as pd
import googlemaps
import time

# %%
#read
df=pd.read_csv("insurance_claims.csv", parse_dates=["policy_bind_date", "incident_date"], index_col="policy_number")

# %%
df['full_address']=df['incident_location'] + ', ' + df['incident_city'] + ', ' + df['incident_state'] + ', ' "US"

# %%
#API Key & Link
API_KEY= "AIzaSyCaDGfe2lSRxFv4vG2tHQ__or3fVMEFJrQ"
gmaps=googlemaps.Client(key=API_KEY)
# list of latitudes / longitudes
latitudes = []
longitudes = []
for address in df['full_address']:
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            # First result
            result = geocode_result[0]
            lat = result['geometry']['location']['lat']
            lng = result['geometry']['location']['lng']
        else:
            lat, lng= None, None
    except Exception as e:
        print(f"Error processing address {address}: {e}")
        lat, lng, None, None
    latitudes.append(lat)
    longitudes.append(lng)
    # API Rate time --> 0.1 second would be ok as well
    time.sleep(0.5)
df['lat'] = latitudes
df['lng'] = longitudes

# %%
df['lat'] = latitudes
df['lng'] = longitudes

# %%
df.head().T
# Out:
# policy_number                                          521585  \
# months_as_customer                                        328
# age                                                        48
# policy_bind_date                          2014-10-17 00:00:00
# policy_state                                               OH
# policy_csl                                            250/500
# policy_deductable                                        1000
# policy_annual_premium                                 1406.91
# umbrella_limit                                              0
# insured_zip                                            466132
# insured_sex                                              MALE
# insured_education_level                                    MD
# insured_occupation                               craft-repair
# insured_hobbies                                      sleeping
# insured_relationship                                  husband
# ...

# %%
df['lat']=df['lat'].fillna(38.33268)
df['lng']=df['lng'].fillna(-81.61616)

# %%
df.to_csv('insurance_claims_geodata.csv')
